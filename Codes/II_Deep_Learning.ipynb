# %%
# Imports
from tensorflow.keras.models import Sequential, model_from_json, Model
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.python.keras.layers import deserialize, serialize
from tensorflow.python.keras.saving import saving_utils
import os
import pandas as pd
import numpy as np
import pickle as pk
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import joblib
from pathlib import Path

import warnings
warnings.filterwarnings('ignore')

# %%
list_nPCs = [10, 15, 20, 25, 30, 35, 40]
takeprofit = 0.12
stoploss = 0.05

# %%
# Load previously built datasets : we just need train sets and validation sets here
trainset_final = pd.read_csv('./Data/Trainset_final_SL{}_TP{}.csv'.format(stoploss, takeprofit))
trainset = pd.read_csv('./Data/Trainset_SL{}_TP{}.csv'.format(stoploss, takeprofit))

validation_set_final = pd.read_csv('./Data/Validationset_final_SL{}_TP{}.csv'.format(stoploss, takeprofit))
validation_set = pd.read_csv('./Data/Validationset_SL{}_TP{}.csv'.format(stoploss, takeprofit))

# %%
# Hotfix function
def unpack(model, training_config, weights):
    restored_model = deserialize(model)
    if training_config is not None:
        restored_model.compile(
            **saving_utils.compile_args_from_training_config(
                training_config
            )
        )
    restored_model.set_weights(weights)
    return restored_model

def make_keras_picklable():
    def __reduce__(self):
        model_metadata = saving_utils.model_metadata(self)
        training_config = model_metadata.get("training_config", None)
        model = serialize(self)
        weights = self.get_weights()
        return (unpack, (model, training_config, weights))
    cls = Model
    cls.__reduce__ = __reduce__

# Run the function
make_keras_picklable()

# %%
# Build and train several models different amounts of PCs
for nPCs in list_nPCs:
    print(nPCs)
    X = trainset_final.iloc[:, :nPCs]
    y = trainset["result"]

    # Build model and train it
    classifier = Sequential()
    dropout_fraction = 0.2
    #First Hidden Layer
    classifier.add(Dense(32, activation='relu', kernel_initializer='random_normal', input_dim=nPCs))
    classifier.add(Dropout(dropout_fraction))
    #Second, third and fourth  hidden Layers
    classifier.add(Dense(32, activation='relu', kernel_initializer='random_normal'))
    classifier.add(Dropout(dropout_fraction))
    classifier.add(Dense(16, activation='relu', kernel_initializer='random_normal'))
    classifier.add(Dropout(dropout_fraction))
    classifier.add(Dense(16, activation='relu', kernel_initializer='random_normal'))
    classifier.add(Dropout(dropout_fraction))

    #Output Layer
    classifier.add(Dense(1, activation='sigmoid', kernel_initializer='random_normal'))
    #Compiling the neural network
    classifier.compile(optimizer ='adam',loss='binary_crossentropy', metrics =['accuracy'])
    #Fitting the data to the training dataset
    classifier.fit(X,y, batch_size=15, epochs=100, verbose =1)

    pk.dump(classifier, open("./Models/DL_model_{}PC_stoploss{}_takeprofit{}.pkl".format(nPCs, stoploss, takeprofit),"wb"))
# Out:
# ======] - 2s 2ms/step - loss: 0.6933 - accuracy: 0.4735
# Epoch 2/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6932 - accuracy: 0.4699
# Epoch 3/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6929 - accuracy: 0.5484
# Epoch 4/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6924 - accuracy: 0.5234
# Epoch 5/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6886 - accuracy: 0.5932
# Epoch 6/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6690 - accuracy: 0.8110
# Epoch 7/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6103 - accuracy: 0.8592
# Epoch 8/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.4769 - accuracy: 0.8957
# Epoch 9/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.3297 - accuracy: 0.9603
# Epoch 10/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2473 - accuracy: 0.9562
# Epoch 11/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.1749 - accuracy: 0.9593
# Epoch 12/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.1104 - accuracy: 0.9781
# Epoch 13/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.1012 - accuracy: 0.9705
# Epoch 14/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0450 - accuracy: 0.9921
# Epoch 15/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0392 - accuracy: 0.9918
# Epoch 16/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0530 - accuracy: 0.9798
# Epoch 17/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0248 - accuracy: 0.9981
# Epoch 18/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0227 - accuracy: 0.9994
# Epoch 19/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0218 - accuracy: 0.9934
# Epoch 20/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0320 - accuracy: 0.9859
# Epoch 21/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0195 - accuracy: 0.9927
# Epoch 22/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0387 - accuracy: 0.9860
# Epoch 23/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0245 - accuracy: 0.9906
# Epoch 24/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0162 - accuracy: 1.0000
# Epoch 25/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0158 - accuracy: 1.0000
# Epoch 26/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0051 - accuracy: 1.0000
# Epoch 27/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0114 - accuracy: 0.9994
# Epoch 28/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0171 - accuracy: 0.9967
# Epoch 29/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0507 - accuracy: 0.9861
# Epoch 30/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0157 - accuracy: 0.9952
# Epoch 31/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0095 - accuracy: 0.9994
# Epoch 32/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0080 - accuracy: 0.9988
# Epoch 33/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0454 - accuracy: 0.9760
# Epoch 34/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0081 - accuracy: 0.9985
# Epoch 35/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0294 - accuracy: 0.9859
# Epoch 36/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0112 - accuracy: 1.0000
# Epoch 37/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0092 - accuracy: 0.9985
# Epoch 38/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0041 - accuracy: 1.0000
# Epoch 39/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0249 - accuracy: 0.9927
# Epoch 40/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0125 - accuracy: 0.9972
# Epoch 41/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0357 - accuracy: 0.9927
# Epoch 42/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 43/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0115 - accuracy: 1.0000
# Epoch 44/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 45/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 46/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0219 - accuracy: 0.9946
# Epoch 47/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0059 - accuracy: 1.0000
# Epoch 48/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0065 - accuracy: 1.0000
# Epoch 49/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0055 - accuracy: 1.0000
# Epoch 50/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0040 - accuracy: 1.0000
# Epoch 51/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0042 - accuracy: 1.0000
# Epoch 52/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0056 - accuracy: 1.0000
# Epoch 53/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0111 - accuracy: 1.0000
# Epoch 54/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 55/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 56/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0130 - accuracy: 0.9901
# Epoch 57/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 58/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0069 - accuracy: 1.0000
# Epoch 59/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0091 - accuracy: 1.0000
# Epoch 60/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0525 - accuracy: 0.9803
# Epoch 61/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 62/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0141 - accuracy: 1.0000
# Epoch 63/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 64/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0052 - accuracy: 0.9972
# Epoch 65/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0074 - accuracy: 1.0000
# Epoch 66/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 67/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0077 - accuracy: 0.9972
# Epoch 68/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 69/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 70/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 71/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 72/100
# 15/15 [==============================] - 0s 2ms/step - loss: 9.9303e-04 - accuracy: 1.0000
# Epoch 73/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 74/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 75/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0065 - accuracy: 1.0000
# Epoch 76/100
# 15/15 [==============================] - 0s 2ms/step - loss: 9.0100e-04 - accuracy: 1.0000
# Epoch 77/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 78/100
# 15/15 [==============================] - 0s 3ms/step - loss: 4.6631e-04 - accuracy: 1.0000
# Epoch 79/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 80/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 81/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 82/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0090 - accuracy: 0.9944
# Epoch 83/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0067 - accuracy: 0.9985
# Epoch 84/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0039 - accuracy: 0.9994
# Epoch 85/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 86/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0278 - accuracy: 0.9907
# Epoch 87/100
# 15/15 [==============================] - 0s 3ms/step - loss: 7.9846e-04 - accuracy: 1.0000
# Epoch 88/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0041 - accuracy: 1.0000
# Epoch 89/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 90/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 91/100
# 15/15 [==============================] - 0s 3ms/step - loss: 7.1884e-04 - accuracy: 1.0000
# Epoch 92/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 93/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0030 - accuracy: 0.9994
# Epoch 94/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 95/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 96/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 97/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0069 - accuracy: 0.9954
# Epoch 98/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 99/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 100/100
# 15/15 [==============================] - 0s 2ms/step - loss: 7.9250e-04 - accuracy: 1.0000
# 40
# Epoch 1/100
# 15/15 [==============================] - 2s 6ms/step - loss: 0.6932 - accuracy: 0.4823
# Epoch 2/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6931 - accuracy: 0.5295
# Epoch 3/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6930 - accuracy: 0.5542
# Epoch 4/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6928 - accuracy: 0.5393
# Epoch 5/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6905 - accuracy: 0.7821
# Epoch 6/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6798 - accuracy: 0.8483
# Epoch 7/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6261 - accuracy: 0.9297
# Epoch 8/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.5019 - accuracy: 0.8963
# Epoch 9/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2807 - accuracy: 0.9371
# Epoch 10/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2254 - accuracy: 0.9425
# Epoch 11/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0880 - accuracy: 0.9814
# Epoch 12/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0936 - accuracy: 0.9641
# Epoch 13/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0644 - accuracy: 0.9664
# Epoch 14/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0410 - accuracy: 0.9925
# Epoch 15/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0395 - accuracy: 0.9994
# Epoch 16/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0310 - accuracy: 0.9946
# Epoch 17/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0187 - accuracy: 0.9972
# Epoch 18/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0192 - accuracy: 0.9946
# Epoch 19/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0152 - accuracy: 1.0000
# Epoch 20/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0286 - accuracy: 0.9946
# Epoch 21/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0093 - accuracy: 1.0000
# Epoch 22/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0095 - accuracy: 0.9959
# Epoch 23/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0244 - accuracy: 0.9967
# Epoch 24/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0136 - accuracy: 0.9975
# Epoch 25/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0116 - accuracy: 1.0000
# Epoch 26/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 1.0000
# Epoch 27/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0198 - accuracy: 0.9907
# Epoch 28/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0188 - accuracy: 0.9907
# Epoch 29/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0071 - accuracy: 0.9988
# Epoch 30/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0162 - accuracy: 0.9859
# Epoch 31/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0046 - accuracy: 1.0000
# Epoch 32/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.9961
# Epoch 33/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 34/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0072 - accuracy: 1.0000
# Epoch 35/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 36/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 37/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 38/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0046 - accuracy: 1.0000
# Epoch 39/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0070 - accuracy: 0.9954
# Epoch 40/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0052 - accuracy: 1.0000
# Epoch 41/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0041 - accuracy: 1.0000
# Epoch 42/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 43/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0203 - accuracy: 0.9954
# Epoch 44/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0264 - accuracy: 0.9853
# Epoch 45/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0087 - accuracy: 0.9935
# Epoch 46/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0399 - accuracy: 0.9913
# Epoch 47/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0057 - accuracy: 0.9972
# Epoch 48/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 49/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0043 - accuracy: 1.0000
# Epoch 50/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0169 - accuracy: 0.9952
# Epoch 51/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 52/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0130 - accuracy: 0.9977
# Epoch 53/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0050 - accuracy: 0.9979
# Epoch 54/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0027 - accuracy: 0.9994
# Epoch 55/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 56/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0075 - accuracy: 0.9972
# Epoch 57/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0128 - accuracy: 0.9977
# Epoch 58/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0074 - accuracy: 1.0000
# Epoch 59/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 60/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0055 - accuracy: 1.0000
# Epoch 61/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 62/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 63/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0051 - accuracy: 1.0000
# Epoch 64/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0281 - accuracy: 0.9866
# Epoch 65/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 66/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 67/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0058 - accuracy: 0.9981
# Epoch 68/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 69/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 70/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0060 - accuracy: 0.9994
# Epoch 71/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.9921
# Epoch 72/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 73/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 74/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 75/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 76/100
# 15/15 [==============================] - 0s 2ms/step - loss: 4.7217e-04 - accuracy: 1.0000
# Epoch 77/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 78/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 79/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 80/100
# 15/15 [==============================] - 0s 2ms/step - loss: 8.7990e-04 - accuracy: 1.0000
# Epoch 81/100
# 15/15 [==============================] - 0s 3ms/step - loss: 9.7241e-04 - accuracy: 1.0000
# Epoch 82/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0045 - accuracy: 1.0000
# Epoch 83/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0567 - accuracy: 0.9846
# Epoch 84/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0093 - accuracy: 1.0000
# Epoch 85/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 86/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 87/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 88/100
# 15/15 [==============================] - 0s 3ms/step - loss: 9.0364e-04 - accuracy: 1.0000
# Epoch 89/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 90/100
# 15/15 [==============================] - 0s 2ms/step - loss: 5.2162e-04 - accuracy: 1.0000
# Epoch 91/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0027 - accuracy: 0.9994
# Epoch 92/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 93/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0094 - accuracy: 0.9901
# Epoch 94/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 95/100
# 15/15 [==============================] - 0s 3ms/step - loss: 2.2488e-04 - accuracy: 1.0000
# Epoch 96/100
# 15/15 [==============================] - 0s 2ms/step - loss: 2.3290e-04 - accuracy: 1.0000
# Epoch 97/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 98/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0062 - accuracy: 1.0000
# Epoch 99/100
# 15/15 [==============================] - 0s 2ms/step - loss: 5.1258e-04 - accuracy: 1.0000
# Epoch 100/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0047 - accuracy: 0.9985

# %%
X_test = validation_set_final
y_test = validation_set['result']

# %%
accuracies, nPCs_list = [], []
for nPCs in list_nPCs:
    print(nPCs)
    with open("./Models/DL_model_{}PC_stoploss{}_takeprofit{}.pkl".format(nPCs, stoploss, takeprofit), 'rb') as f:
        clf = pk.load(f)
    # Compute predictions on testset
    preds = (clf.predict(validation_set_final.iloc[:, :nPCs]) > 0.5)*1

    # Assess accuracy on Bullish predictions only (because we assume only performing Bullish trades) 
    validation_set1 = validation_set[preds == 1].copy()
    accuracies.append(np.mean(preds == list(validation_set['result'])))
    nPCs_list.append(nPCs)
# Out:
# 10
# 15
# 20
# 25
# 30
# WARNING:tensorflow:5 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000025E7CFDE288> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 35
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000025E7CE26B88> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 40
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000025E7E5BEC18> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
recap = pd.DataFrame({'nPCs' : list(nPCs_list), 'Accuracy' : (list(accuracies))})
recap.to_csv('./Results/Comparative_All_models_stoploss{}_takeprofit{}.csv'.format(stoploss, takeprofit), index = False)
print(recap)
# Out:
#    nPCs  Accuracy
# 0    10  0.624444
# 1    15  0.615556
# 2    20  0.513333
# 3    25  0.500000
# 4    30  0.553333
# 5    35  0.557778
# 6    40  0.486667

# %%
print(clf.summary())
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_30 (Dense)             (None, 32)                1312
# _________________________________________________________________
# dropout_24 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_31 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dropout_25 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_32 (Dense)             (None, 16)                528
# _________________________________________________________________
# dropout_26 (Dropout)         (None, 16)                0
# _________________________________________________________________
# dense_33 (Dense)             (None, 16)                272
# _________________________________________________________________
# dropout_27 (Dropout)         (None, 16)                0
# _________________________________________________________________
# dense_34 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 3,185
# Trainable params: 3,185
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
import tensorflow as tf

X = trainset_final.iloc[:, :10]
y = trainset["result"]
X_val = validation_set_final.iloc[:, :10]
y_val = validation_set['result']
# Build model and train it
classifier = Sequential()
dropout_fraction = 0.2
# First Hidden Layer
classifier.add(Dense(32, activation='relu', kernel_initializer='random_normal', input_dim=10))
classifier.add(Dropout(dropout_fraction))
# Second, third and fourth hidden Layers
classifier.add(Dense(32, activation='relu', kernel_initializer='random_normal'))
classifier.add(Dropout(dropout_fraction))
classifier.add(Dense(16, activation='relu', kernel_initializer='random_normal'))
classifier.add(Dropout(dropout_fraction))
classifier.add(Dense(16, activation='relu', kernel_initializer='random_normal'))
classifier.add(Dropout(dropout_fraction))

# Output Layer
classifier.add(Dense(1, activation='sigmoid', kernel_initializer='random_normal'))
# Compiling the neural network
classifier.compile(optimizer ='adam',loss='binary_crossentropy', metrics =[
    "accuracy",
    tf.keras.metrics.TruePositives(name="tp"),
    tf.keras.metrics.TrueNegatives(name="tn"),
    tf.keras.metrics.FalsePositives(name="fp"),
    tf.keras.metrics.FalseNegatives(name="fn"),
    tf.keras.metrics.Precision(name="precision"),
    tf.keras.metrics.Recall(name="recall"),
    tf.keras.metrics.AUC(name="auc"),
    ])
# Fitting the data to the training dataset
model = classifier.fit(X,y, batch_size=15, epochs=100, validation_data=(X_val, y_val), verbose =1)
# Out:
# =========================] - 0s 10ms/step - loss: 0.2403 - accuracy: 0.9174 - tp: 56.4375 - tn: 59.2500 - fp: 8.1250 - fn: 2.2500 - precision: 0.8617 - recall: 0.9750 - auc: 0.9623 - val_loss: 6.2928 - val_accuracy: 0.6167 - val_tp: 1.0000 - val_tn: 36.0000 - val_fp: 2.0000 - val_fn: 21.0000 - val_precision: 0.3333 - val_recall: 0.0455 - val_auc: 0.4970
# Epoch 51/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.1757 - accuracy: 0.9347 - tp: 54.6875 - tn: 62.6875 - fp: 4.2500 - fn: 4.4375 - precision: 0.9241 - recall: 0.9305 - auc: 0.9754 - val_loss: 6.2426 - val_accuracy: 0.6000 - val_tp: 0.0000e+00 - val_tn: 36.0000 - val_fp: 2.0000 - val_fn: 22.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.4970
# Epoch 52/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.1641 - accuracy: 0.9588 - tp: 59.1875 - tn: 61.1250 - fp: 4.6250 - fn: 1.1250 - precision: 0.9341 - recall: 0.9832 - auc: 0.9808 - val_loss: 6.2667 - val_accuracy: 0.6000 - val_tp: 0.0000e+00 - val_tn: 36.0000 - val_fp: 2.0000 - val_fn: 22.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.4575
# Epoch 53/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.1946 - accuracy: 0.9357 - tp: 61.6250 - tn: 57.0000 - fp: 6.6875 - fn: 0.7500 - precision: 0.8915 - recall: 0.9922 - auc: 0.9687 - val_loss: 6.8303 - val_accuracy: 0.6000 - val_tp: 0.0000e+00 - val_tn: 36.0000 - val_fp: 2.0000 - val_fn: 22.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.4575
# Epoch 54/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.1576 - accuracy: 0.9530 - tp: 56.3750 - tn: 63.3125 - fp: 4.1875 - fn: 2.1875 - precision: 0.9288 - recall: 0.9711 - auc: 0.9806 - val_loss: 7.0014 - val_accuracy: 0.6000 - val_tp: 0.0000e+00 - val_tn: 36.0000 - val_fp: 2.0000 - val_fn: 22.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.4575
# Epoch 55/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.2508 - accuracy: 0.9363 - tp: 59.0000 - tn: 58.8750 - fp: 6.5625 - fn: 1.6250 - precision: 0.9010 - recall: 0.9759 - auc: 0.9520 - val_loss: 7.3116 - val_accuracy: 0.6000 - val_tp: 0.0000e+00 - val_tn: 36.0000 - val_fp: 2.0000 - val_fn: 22.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.4904
# Epoch 56/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1373 - accuracy: 0.9588 - tp: 58.6250 - tn: 62.0625 - fp: 3.8125 - fn: 1.5625 - precision: 0.9312 - recall: 0.9806 - auc: 0.9845 - val_loss: 7.2771 - val_accuracy: 0.6167 - val_tp: 1.0000 - val_tn: 36.0000 - val_fp: 2.0000 - val_fn: 21.0000 - val_precision: 0.3333 - val_recall: 0.0455 - val_auc: 0.4779
# Epoch 57/100
# 15/15 [==============================] - 0s 10ms/step - loss: 0.1695 - accuracy: 0.9427 - tp: 57.3750 - tn: 61.5625 - fp: 3.5000 - fn: 3.6250 - precision: 0.9492 - recall: 0.9359 - auc: 0.9746 - val_loss: 7.1854 - val_accuracy: 0.6000 - val_tp: 0.0000e+00 - val_tn: 36.0000 - val_fp: 2.0000 - val_fn: 22.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.4779
# Epoch 58/100
# 15/15 [==============================] - 0s 10ms/step - loss: 0.1463 - accuracy: 0.9677 - tp: 62.8125 - tn: 58.6250 - fp: 4.1875 - fn: 0.4375 - precision: 0.9444 - recall: 0.9953 - auc: 0.9825 - val_loss: 7.0152 - val_accuracy: 0.6167 - val_tp: 1.0000 - val_tn: 36.0000 - val_fp: 2.0000 - val_fn: 21.0000 - val_precision: 0.3333 - val_recall: 0.0455 - val_auc: 0.4647
# Epoch 59/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.2054 - accuracy: 0.9147 - tp: 57.1250 - tn: 58.5000 - fp: 7.5625 - fn: 2.8750 - precision: 0.8741 - recall: 0.9442 - auc: 0.9695 - val_loss: 7.5634 - val_accuracy: 0.6000 - val_tp: 0.0000e+00 - val_tn: 36.0000 - val_fp: 2.0000 - val_fn: 22.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.4575
# Epoch 60/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.1692 - accuracy: 0.9586 - tp: 60.4375 - tn: 60.4375 - fp: 3.2500 - fn: 1.9375 - precision: 0.9467 - recall: 0.9726 - auc: 0.9809 - val_loss: 8.0885 - val_accuracy: 0.6000 - val_tp: 0.0000e+00 - val_tn: 36.0000 - val_fp: 2.0000 - val_fn: 22.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.4904
# Epoch 61/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.1383 - accuracy: 0.9605 - tp: 62.3750 - tn: 57.8125 - fp: 5.0000 - fn: 0.8750 - precision: 0.9356 - recall: 0.9897 - auc: 0.9837 - val_loss: 8.5645 - val_accuracy: 0.6000 - val_tp: 0.0000e+00 - val_tn: 36.0000 - val_fp: 2.0000 - val_fn: 22.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.4701
# Epoch 62/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.1776 - accuracy: 0.9513 - tp: 59.9375 - tn: 59.5625 - fp: 4.0625 - fn: 2.5000 - precision: 0.9490 - recall: 0.9566 - auc: 0.9787 - val_loss: 8.2928 - val_accuracy: 0.6000 - val_tp: 0.0000e+00 - val_tn: 36.0000 - val_fp: 2.0000 - val_fn: 22.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.4701
# Epoch 63/100
# 15/15 [==============================] - 0s 10ms/step - loss: 0.1670 - accuracy: 0.9200 - tp: 55.0000 - tn: 60.6250 - fp: 3.0000 - fn: 7.4375 - precision: 0.9647 - recall: 0.8715 - auc: 0.9842 - val_loss: 7.3741 - val_accuracy: 0.6000 - val_tp: 0.0000e+00 - val_tn: 36.0000 - val_fp: 2.0000 - val_fn: 22.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.4701
# Epoch 64/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1764 - accuracy: 0.9546 - tp: 61.9375 - tn: 57.8125 - fp: 6.3125 - fn: 0.0000e+00 - precision: 0.9168 - recall: 1.0000 - auc: 0.9721 - val_loss: 7.5290 - val_accuracy: 0.6000 - val_tp: 0.0000e+00 - val_tn: 36.0000 - val_fp: 2.0000 - val_fn: 22.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.4701
# Epoch 65/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.2032 - accuracy: 0.9386 - tp: 60.6875 - tn: 58.8125 - fp: 4.8750 - fn: 1.6875 - precision: 0.9080 - recall: 0.9753 - auc: 0.9569 - val_loss: 8.0177 - val_accuracy: 0.6000 - val_tp: 0.0000e+00 - val_tn: 36.0000 - val_fp: 2.0000 - val_fn: 22.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.4701
# Epoch 66/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.1238 - accuracy: 0.9793 - tp: 64.9375 - tn: 57.6250 - fp: 2.6875 - fn: 0.8125 - precision: 0.9686 - recall: 0.9921 - auc: 0.9808 - val_loss: 8.3513 - val_accuracy: 0.6000 - val_tp: 0.0000e+00 - val_tn: 36.0000 - val_fp: 2.0000 - val_fn: 22.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.4701
# Epoch 67/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.1755 - accuracy: 0.9512 - tp: 60.0625 - tn: 59.1875 - fp: 5.5625 - fn: 1.2500 - precision: 0.9219 - recall: 0.9821 - auc: 0.9738 - val_loss: 8.5136 - val_accuracy: 0.6000 - val_tp: 0.0000e+00 - val_tn: 36.0000 - val_fp: 2.0000 - val_fn: 22.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.4701
# Epoch 68/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.1820 - accuracy: 0.9471 - tp: 60.9375 - tn: 59.3125 - fp: 3.9375 - fn: 1.8750 - precision: 0.9355 - recall: 0.9649 - auc: 0.9780 - val_loss: 8.5615 - val_accuracy: 0.6000 - val_tp: 0.0000e+00 - val_tn: 36.0000 - val_fp: 2.0000 - val_fn: 22.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.4701
# Epoch 69/100
# 15/15 [==============================] - 0s 10ms/step - loss: 0.1771 - accuracy: 0.9477 - tp: 61.1250 - tn: 58.7500 - fp: 5.5625 - fn: 0.6250 - precision: 0.9125 - recall: 0.9920 - auc: 0.9680 - val_loss: 7.5130 - val_accuracy: 0.6000 - val_tp: 0.0000e+00 - val_tn: 36.0000 - val_fp: 2.0000 - val_fn: 22.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.4773
# Epoch 70/100
# 15/15 [==============================] - 0s 10ms/step - loss: 0.1880 - accuracy: 0.9249 - tp: 53.6875 - tn: 64.0000 - fp: 5.5625 - fn: 2.8125 - precision: 0.8804 - recall: 0.9546 - auc: 0.9713 - val_loss: 7.7136 - val_accuracy: 0.6000 - val_tp: 0.0000e+00 - val_tn: 36.0000 - val_fp: 2.0000 - val_fn: 22.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.4773
# Epoch 71/100
# 15/15 [==============================] - 0s 10ms/step - loss: 0.2213 - accuracy: 0.9343 - tp: 57.7500 - tn: 61.3750 - fp: 5.1250 - fn: 1.8125 - precision: 0.8964 - recall: 0.9710 - auc: 0.9613 - val_loss: 8.1160 - val_accuracy: 0.6000 - val_tp: 0.0000e+00 - val_tn: 36.0000 - val_fp: 2.0000 - val_fn: 22.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.4575
# Epoch 72/100
# 15/15 [==============================] - 0s 10ms/step - loss: 0.1829 - accuracy: 0.9420 - tp: 60.6875 - tn: 58.5000 - fp: 5.0625 - fn: 1.8125 - precision: 0.9244 - recall: 0.9656 - auc: 0.9740 - val_loss: 7.9392 - val_accuracy: 0.6000 - val_tp: 0.0000e+00 - val_tn: 36.0000 - val_fp: 2.0000 - val_fn: 22.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.4575
# Epoch 73/100
# 15/15 [==============================] - 0s 10ms/step - loss: 0.2427 - accuracy: 0.9296 - tp: 62.9375 - tn: 56.0625 - fp: 6.2500 - fn: 0.8125 - precision: 0.8797 - recall: 0.9871 - auc: 0.9592 - val_loss: 8.6628 - val_accuracy: 0.6000 - val_tp: 0.0000e+00 - val_tn: 36.0000 - val_fp: 2.0000 - val_fn: 22.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.4575
# Epoch 74/100
# 15/15 [==============================] - 0s 10ms/step - loss: 0.2590 - accuracy: 0.9392 - tp: 57.1875 - tn: 61.6250 - fp: 3.9375 - fn: 3.3125 - precision: 0.9334 - recall: 0.9426 - auc: 0.9526 - val_loss: 8.8011 - val_accuracy: 0.6000 - val_tp: 0.0000e+00 - val_tn: 36.0000 - val_fp: 2.0000 - val_fn: 22.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.4701
# Epoch 75/100
# 15/15 [==============================] - 0s 10ms/step - loss: 0.1707 - accuracy: 0.9727 - tp: 61.6875 - tn: 60.3750 - fp: 3.6250 - fn: 0.3750 - precision: 0.9508 - recall: 0.9961 - auc: 0.9664 - val_loss: 8.8186 - val_accuracy: 0.6000 - val_tp: 0.0000e+00 - val_tn: 36.0000 - val_fp: 2.0000 - val_fn: 22.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.4701
# Epoch 76/100
# 15/15 [==============================] - 0s 10ms/step - loss: 0.1220 - accuracy: 0.9669 - tp: 60.5625 - tn: 60.1250 - fp: 4.6875 - fn: 0.6875 - precision: 0.9450 - recall: 0.9906 - auc: 0.9880 - val_loss: 8.7321 - val_accuracy: 0.6000 - val_tp: 0.0000e+00 - val_tn: 36.0000 - val_fp: 2.0000 - val_fn: 22.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.4575
# Epoch 77/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1903 - accuracy: 0.9476 - tp: 60.7500 - tn: 59.0000 - fp: 4.8750 - fn: 1.4375 - precision: 0.9186 - recall: 0.9790 - auc: 0.9673 - val_loss: 9.0004 - val_accuracy: 0.6000 - val_tp: 0.0000e+00 - val_tn: 36.0000 - val_fp: 2.0000 - val_fn: 22.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.4701
# Epoch 78/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1807 - accuracy: 0.9381 - tp: 58.8750 - tn: 59.4375 - fp: 6.2500 - fn: 1.5000 - precision: 0.8990 - recall: 0.9782 - auc: 0.9758 - val_loss: 9.6054 - val_accuracy: 0.6000 - val_tp: 0.0000e+00 - val_tn: 36.0000 - val_fp: 2.0000 - val_fn: 22.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.4701
# Epoch 79/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.1317 - accuracy: 0.9803 - tp: 60.7500 - tn: 62.1875 - fp: 3.0000 - fn: 0.1250 - precision: 0.9625 - recall: 0.9988 - auc: 0.9800 - val_loss: 10.1833 - val_accuracy: 0.6000 - val_tp: 0.0000e+00 - val_tn: 36.0000 - val_fp: 2.0000 - val_fn: 22.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.4952
# Epoch 80/100
# 15/15 [==============================] - 0s 10ms/step - loss: 0.1370 - accuracy: 0.9502 - tp: 57.3125 - tn: 62.0000 - fp: 3.5000 - fn: 3.2500 - precision: 0.9508 - recall: 0.9456 - auc: 0.9877 - val_loss: 9.7240 - val_accuracy: 0.6000 - val_tp: 0.0000e+00 - val_tn: 36.0000 - val_fp: 2.0000 - val_fn: 22.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.4701
# Epoch 81/100
# 15/15 [==============================] - 0s 10ms/step - loss: 0.1227 - accuracy: 0.9625 - tp: 57.2500 - tn: 63.5625 - fp: 4.8750 - fn: 0.3750 - precision: 0.9254 - recall: 0.9964 - auc: 0.9898 - val_loss: 10.0855 - val_accuracy: 0.6000 - val_tp: 0.0000e+00 - val_tn: 36.0000 - val_fp: 2.0000 - val_fn: 22.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.4827
# Epoch 82/100
# 15/15 [==============================] - 0s 13ms/step - loss: 0.1131 - accuracy: 0.9744 - tp: 60.3750 - tn: 61.8750 - fp: 3.8125 - fn: 0.0000e+00 - precision: 0.9495 - recall: 1.0000 - auc: 0.9828 - val_loss: 10.4024 - val_accuracy: 0.6000 - val_tp: 0.0000e+00 - val_tn: 36.0000 - val_fp: 2.0000 - val_fn: 22.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.4952
# Epoch 83/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1451 - accuracy: 0.9740 - tp: 58.1875 - tn: 63.8750 - fp: 1.8750 - fn: 2.1250 - precision: 0.9797 - recall: 0.9657 - auc: 0.9829 - val_loss: 10.3943 - val_accuracy: 0.6000 - val_tp: 0.0000e+00 - val_tn: 36.0000 - val_fp: 2.0000 - val_fn: 22.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.4952
# Epoch 84/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.2083 - accuracy: 0.9378 - tp: 59.2500 - tn: 60.0000 - fp: 4.3750 - fn: 2.4375 - precision: 0.9199 - recall: 0.9576 - auc: 0.9582 - val_loss: 10.7569 - val_accuracy: 0.6000 - val_tp: 0.0000e+00 - val_tn: 36.0000 - val_fp: 2.0000 - val_fn: 22.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.4952
# Epoch 85/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.1812 - accuracy: 0.9288 - tp: 57.6250 - tn: 61.3750 - fp: 3.3750 - fn: 3.6875 - precision: 0.9491 - recall: 0.9088 - auc: 0.9734 - val_loss: 10.4331 - val_accuracy: 0.6000 - val_tp: 0.0000e+00 - val_tn: 36.0000 - val_fp: 2.0000 - val_fn: 22.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.4952
# Epoch 86/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1542 - accuracy: 0.9488 - tp: 59.2500 - tn: 60.6875 - fp: 6.1250 - fn: 0.0000e+00 - precision: 0.8990 - recall: 1.0000 - auc: 0.9796 - val_loss: 10.8311 - val_accuracy: 0.6000 - val_tp: 0.0000e+00 - val_tn: 36.0000 - val_fp: 2.0000 - val_fn: 22.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.4952
# Epoch 87/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1345 - accuracy: 0.9605 - tp: 59.1250 - tn: 61.3125 - fp: 4.1250 - fn: 1.5000 - precision: 0.9395 - recall: 0.9813 - auc: 0.9888 - val_loss: 11.0733 - val_accuracy: 0.6000 - val_tp: 0.0000e+00 - val_tn: 36.0000 - val_fp: 2.0000 - val_fn: 22.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.4952
# Epoch 88/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.1329 - accuracy: 0.9633 - tp: 62.8750 - tn: 58.3750 - fp: 3.6875 - fn: 1.1250 - precision: 0.9479 - recall: 0.9823 - auc: 0.9867 - val_loss: 10.9979 - val_accuracy: 0.6000 - val_tp: 0.0000e+00 - val_tn: 36.0000 - val_fp: 2.0000 - val_fn: 22.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.4952
# Epoch 89/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.1863 - accuracy: 0.9433 - tp: 61.5000 - tn: 59.3125 - fp: 5.2500 - fn: 0.0000e+00 - precision: 0.8944 - recall: 1.0000 - auc: 0.9687 - val_loss: 11.2360 - val_accuracy: 0.6000 - val_tp: 0.0000e+00 - val_tn: 36.0000 - val_fp: 2.0000 - val_fn: 22.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.4952
# Epoch 90/100
# 15/15 [==============================] - 0s 13ms/step - loss: 0.1015 - accuracy: 0.9729 - tp: 62.9375 - tn: 58.9375 - fp: 2.1875 - fn: 2.0000 - precision: 0.9759 - recall: 0.9721 - auc: 0.9934 - val_loss: 11.2816 - val_accuracy: 0.6000 - val_tp: 0.0000e+00 - val_tn: 36.0000 - val_fp: 2.0000 - val_fn: 22.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.4952
# Epoch 91/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.2025 - accuracy: 0.9473 - tp: 61.5625 - tn: 58.4375 - fp: 5.7500 - fn: 0.3125 - precision: 0.9058 - recall: 0.9968 - auc: 0.9584 - val_loss: 11.2943 - val_accuracy: 0.6000 - val_tp: 0.0000e+00 - val_tn: 36.0000 - val_fp: 2.0000 - val_fn: 22.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.4952
# Epoch 92/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.1921 - accuracy: 0.9144 - tp: 64.2500 - tn: 53.3125 - fp: 3.5000 - fn: 5.0000 - precision: 0.9433 - recall: 0.9117 - auc: 0.9752 - val_loss: 11.0354 - val_accuracy: 0.6000 - val_tp: 0.0000e+00 - val_tn: 36.0000 - val_fp: 2.0000 - val_fn: 22.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.4952
# Epoch 93/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.1859 - accuracy: 0.9455 - tp: 60.2500 - tn: 58.6250 - fp: 5.3125 - fn: 1.8750 - precision: 0.9233 - recall: 0.9726 - auc: 0.9649 - val_loss: 10.6400 - val_accuracy: 0.6000 - val_tp: 0.0000e+00 - val_tn: 36.0000 - val_fp: 2.0000 - val_fn: 22.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.4701
# Epoch 94/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.1202 - accuracy: 0.9621 - tp: 56.3125 - tn: 64.6250 - fp: 3.3125 - fn: 1.8125 - precision: 0.9573 - recall: 0.9602 - auc: 0.9883 - val_loss: 10.0646 - val_accuracy: 0.6000 - val_tp: 0.0000e+00 - val_tn: 36.0000 - val_fp: 2.0000 - val_fn: 22.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.4701
# Epoch 95/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.0981 - accuracy: 0.9700 - tp: 56.8125 - tn: 64.9375 - fp: 3.4375 - fn: 0.8750 - precision: 0.9537 - recall: 0.9822 - auc: 0.9916 - val_loss: 11.0112 - val_accuracy: 0.6000 - val_tp: 0.0000e+00 - val_tn: 36.0000 - val_fp: 2.0000 - val_fn: 22.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.4827
# Epoch 96/100
# 15/15 [==============================] - 0s 13ms/step - loss: 0.1616 - accuracy: 0.9418 - tp: 64.2500 - tn: 55.0625 - fp: 4.4375 - fn: 2.3125 - precision: 0.9301 - recall: 0.9682 - auc: 0.9813 - val_loss: 11.3844 - val_accuracy: 0.6167 - val_tp: 0.0000e+00 - val_tn: 37.0000 - val_fp: 1.0000 - val_fn: 22.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.4952
# Epoch 97/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1269 - accuracy: 0.9672 - tp: 59.3125 - tn: 62.4375 - fp: 3.9375 - fn: 0.3750 - precision: 0.9365 - recall: 0.9965 - auc: 0.9829 - val_loss: 11.6232 - val_accuracy: 0.6000 - val_tp: 0.0000e+00 - val_tn: 36.0000 - val_fp: 2.0000 - val_fn: 22.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.4952
# Epoch 98/100
# 15/15 [==============================] - 0s 10ms/step - loss: 0.1253 - accuracy: 0.9662 - tp: 59.1250 - tn: 61.8750 - fp: 3.1875 - fn: 1.8750 - precision: 0.9591 - recall: 0.9714 - auc: 0.9898 - val_loss: 11.2266 - val_accuracy: 0.6000 - val_tp: 0.0000e+00 - val_tn: 36.0000 - val_fp: 2.0000 - val_fn: 22.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.4827
# Epoch 99/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.1351 - accuracy: 0.9477 - tp: 60.1875 - tn: 60.3125 - fp: 4.1875 - fn: 1.3750 - precision: 0.9289 - recall: 0.9672 - auc: 0.9847 - val_loss: 11.9727 - val_accuracy: 0.6000 - val_tp: 0.0000e+00 - val_tn: 36.0000 - val_fp: 2.0000 - val_fn: 22.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.4952
# Epoch 100/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.2202 - accuracy: 0.9288 - tp: 58.3750 - tn: 60.1250 - fp: 3.6250 - fn: 3.9375 - precision: 0.9382 - recall: 0.9189 - auc: 0.9634 - val_loss: 12.0982 - val_accuracy: 0.6167 - val_tp: 0.0000e+00 - val_tn: 37.0000 - val_fp: 1.0000 - val_fn: 22.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.4952

# %%
epochs = 100

# %%
loss_df = pd.DataFrame(
    {
        "Epoch": range(1, epochs + 1),
        "Train": model.history["loss"],
        "Val": model.history["val_loss"],
    }
)
print(loss_df)
loss_df.set_index("Epoch", inplace=True)
loss_df.plot(title="Loss")
# Out:
#     Epoch     Train        Val
# 0       1  0.693153   0.692954
# 1       2  0.693182   0.693112
# 2       3  0.692874   0.691977
# 3       4  0.691953   0.689755
# 4       5  0.687144   0.679650
# 5       6  0.667972   0.646816
# 6       7  0.607840   0.637030
# 7       8  0.552326   0.800352
# 8       9  0.497715   0.879990
# 9      10  0.460343   0.952721
# 10     11  0.415119   1.097705
# 11     12  0.371828   1.267400
# 12     13  0.388434   1.392817
# 13     14  0.357862   1.734571
# 14     15  0.318085   1.738253
# 15     16  0.331908   1.864074
# 16     17  0.316284   2.052934
# 17     18  0.309935   2.360882
# 18     19  0.335855   2.345173
# 19     20  0.264860   2.670964
# 20     21  0.270333   2.860036
# 21     22  0.269904   2.851962
# 22     23  0.291299   3.067611
# 23     24  0.246261   3.415552
# 24     25  0.238809   3.899911
# 25     26  0.269903   4.097299
# 26     27  0.243972   4.053729
# 27     28  0.227850   4.119299
# 28     29  0.244391   4.200919
# 29     30  0.242321   4.052351
# ..    ...       ...        ...
# 70     71  0.161575   8.115970
# 71     72  0.177570   7.939186
# 72     73  0.156400   8.662785
# 73     74  0.194750   8.801085
# 74     75  0.162712   8.818555
# 75     76  0.185786   8.732114
# 76     77  0.160646   9.000384
# 77     78  0.181685   9.605441
# 78     79  0.160533  10.183339
# 79     80  0.143585   9.724027
# 80     81  0.155657  10.085508
# 81     82  0.126029  10.402409
# 82     83  0.155560  10.394326
# 83     84  0.152215  10.756944
# 84     85  0.165027  10.433109
# 85     86  0.144776  10.831065
# 86     87  0.133394  11.073274
# 87     88  0.164341  10.997906
# 88     89  0.124246  11.235961
# 89     90  0.134871  11.281585
# 90     91  0.157211  11.294298
# 91     92  0.143132  11.035413
# 92     93  0.185323  10.640015
# 93     94  0.137191  10.064600
# 94     95  0.116995  11.011191
# 95     96  0.183182  11.384398
# 96     97  0.175374  11.623219
# 97     98  0.132887  11.226602
# 98     99  0.119259  11.972654
# 99    100  0.146599  12.098205
#
# [100 rows x 3 columns]
#
# Bad key "text.kerning_factor" on line 4 in
# C:\Users\Josh Bond\Anaconda3\envs\dev\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution

# %%
accuracy_df = pd.DataFrame(
    {
        "Epoch": range(1, epochs + 1),
        "Train": model.history["accuracy"],
        "Val": model.history["val_accuracy"],
    }
)
accuracy_df.set_index("Epoch", inplace=True)
accuracy_df.plot(title="Accuracy")

# %%
# Plotting AUC
auc_df = pd.DataFrame(
    {
        "Epoch": range(1, epochs + 1),
        "Train": model.history["auc"],
        "Val": model.history["val_auc"],
    }
)
auc_df.set_index("Epoch", inplace=True)
auc_df.plot(title="AUC")

# %%
results = validation_set.copy()

# %%
results['preds'] = preds

# %%
results = results[['result','preds']]

# %%
results
# Out:
#     result  preds
# 0        1      0
# 1        0      0
# 2        1      0
# 3        1      0
# 4        0      0
# 5        0      0
# 6        1      0
# 7        1      0
# 8        0      0
# 9        0      0
# 10       1      0
# 11       1      0
# 12       0      0
# 13       0      0
# 14       0      0
# 15       0      0
# 16       0      0
# 17       0      0
# 18       0      0
# 19       0      0
# 20       0      0
# 21       0      0
# 22       1      1
# 23       0      0
# 24       0      0
# 25       0      0
# 26       0      1
# 27       0      1
# 28       0      1
# 29       0      1
# 30       0      1
# 31       1      1
# 32       0      1
# 33       0      1
# 34       0      1
# 35       0      1
# 36       0      1
# 37       1      1
# 38       0      1
# 39       0      1
# 40       0      1
# 41       1      1
# 42       1      1
# 43       0      1
# 44       0      1
# 45       1      1
# 46       1      1
# 47       1      1
# 48       1      1
# 49       0      0
# 50       0      1
# 51       1      1
# 52       0      0
# 53       1      1
# 54       1      1
# 55       0      1
# 56       1      1
# 57       1      1
# 58       0      1
# 59       1      1
